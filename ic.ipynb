# %% [markdown]
# <a href="https://colab.research.google.com/github/NathaliaOliveir/Analise-Multivariada/blob/main/ic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mne

# %%
pip install tensorpac

# %%
#IMPORTAR OS DADOS
import numpy as np
import mne
import os
import tensorpac
import sklearn

file_path = os.path.expanduser('/content/chb01_01.edf')

print(f"Tentando carregar o arquivo de EEG de: {file_path}")

try:
    raw = mne.io.read_raw_edf(file_path, preload=True)

    print("\n--- Carregamento Concluído ---")
    print(raw)

except FileNotFoundError:
    print("\nERRO: Arquivo não encontrado! Verifique o caminho.")
# Out:
# Tentando carregar o arquivo de EEG de: /content/chb01_01.edf
# Extracting EDF parameters from /content/chb01_01.edf...
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# /tmp/ipykernel_8915/2671010169.py:13: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_path, preload=True)
# --- Carregamento Concluído ---
# <RawEDF | chb01_01.edf, 23 x 921600 (3600.0 s), ~161.7 MiB, data loaded>
